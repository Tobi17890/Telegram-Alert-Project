# %%
import pyodbc

print(pyodbc.drivers())
# Out:
# ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)']

# %%
import pyodbc
from getpass import getpass

server = "172.17.1.197"
database = "DataMart_CMCR_User"
username = "YOUR_DB_USERNAME"
password = getpass("Enter database password: ")

conn = pyodbc.connect(
    "DRIVER={SQL Server};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password};"
)

print("Connected successfully")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[2], line 9
#       5 database = "DataMart_CMCR_User"
#       6 username = "YOUR_DB_USERNAME"
#       7 password = getpass("Enter database password: ")
#       8
# ----> 9 conn = pyodbc.connect(
#      10     "DRIVER={SQL Server};"
#      11     f"SERVER={server};"
#      12     f"DATABASE={database};"
#
# InterfaceError: ('28000', "[28000] [Microsoft][ODBC SQL Server Driver][SQL Server]Login failed for user 'YOUR_DB_USERNAME'. (18456) (SQLDriverConnect); [28000] [Microsoft][ODBC SQL Server Driver][SQL Server]Login failed for user 'YOUR_DB_USERNAME'. (18456)")
